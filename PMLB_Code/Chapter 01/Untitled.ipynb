# %%
import requests
r=requests.get(r"https://api.github.com/users/acombs/starred")
r.json()
# Out:
# [{'archive_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/branches{/branch}',
#   'clone_url': 'https://github.com/Esri/spatial-framework-for-hadoop.git',
#   'collaborators_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/contributors',
#   'created_at': '2013-01-11T17:25:28Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/deployments',
#   'description': 'The Spatial Framework for Hadoop allows developers and data scientists to use the Hadoop data processing system for spatial data analysis.',
#   'downloads_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/downloads',
#   'events_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/events',
#   'fork': False,
#   'forks': 112,
#   'forks_count': 112,
#   'forks_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/forks',
#   'full_name': 'Esri/spatial-framework-for-hadoop',
#   'git_commits_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/git/tags{/sha}',
#   'git_url': 'git://github.com/Esri/spatial-framework-for-hadoop.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': True,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': '',
#   'hooks_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/hooks',
#   'html_url': 'https://github.com/Esri/spatial-framework-for-hadoop',
#   'id': 7563814,
#   'issue_comment_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/labels{/name}',
#   'language': 'Java',
#   'languages_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/languages',
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0'},
#   'merges_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/merges',
#   'milestones_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/milestones{/number}',
#   'mirror_url': None,
#   'name': 'spatial-framework-for-hadoop',
#   'notifications_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/notifications{?since,all,participating}',
#   'open_issues': 21,
#   'open_issues_count': 21,
#   'owner': {'avatar_url': 'https://avatars1.githubusercontent.com/u/628795?v=4',
#    'events_url': 'https://api.github.com/users/Esri/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/Esri/followers',
#    'following_url': 'https://api.github.com/users/Esri/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Esri/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/Esri',
#    'id': 628795,
#    'login': 'Esri',
#    'organizations_url': 'https://api.github.com/users/Esri/orgs',
#    'received_events_url': 'https://api.github.com/users/Esri/received_events',
#    'repos_url': 'https://api.github.com/users/Esri/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/Esri/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Esri/subscriptions',
#    'type': 'Organization',
#    'url': 'https://api.github.com/users/Esri'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/pulls{/number}',
#   'pushed_at': '2018-02-26T23:56:04Z',
#   'releases_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/releases{/id}',
#   'size': 5541,
#   'ssh_url': 'git@github.com:Esri/spatial-framework-for-hadoop.git',
#   'stargazers_count': 206,
#   'stargazers_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/stargazers',
#   'statuses_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/subscription',
#   'svn_url': 'https://github.com/Esri/spatial-framework-for-hadoop',
#   'tags_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/tags',
#   'teams_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/teams',
#   'trees_url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop/git/trees{/sha}',
#   'updated_at': '2018-02-27T07:57:25Z',
#   'url': 'https://api.github.com/repos/Esri/spatial-framework-for-hadoop',
#   'watchers': 206,
#   'watchers_count': 206},
#  {'archive_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/branches{/branch}',
#   'clone_url': 'https://github.com/vaquarkhan/vk-wiki-notes.git',
#   'collaborators_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/contributors',
#   'created_at': '2016-08-05T03:43:14Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/deployments',
#   'description': None,
#   'downloads_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/downloads',
#   'events_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/events',
#   'fork': False,
#   'forks': 19,
#   'forks_count': 19,
#   'forks_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/forks',
#   'full_name': 'vaquarkhan/vk-wiki-notes',
#   'git_commits_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/git/tags{/sha}',
#   'git_url': 'git://github.com/vaquarkhan/vk-wiki-notes.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/hooks',
#   'html_url': 'https://github.com/vaquarkhan/vk-wiki-notes',
#   'id': 64986640,
#   'issue_comment_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/labels{/name}',
#   'language': 'Scala',
#   'languages_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/merges',
#   'milestones_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/milestones{/number}',
#   'mirror_url': None,
#   'name': 'vk-wiki-notes',
#   'notifications_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars3.githubusercontent.com/u/3491908?v=4',
#    'events_url': 'https://api.github.com/users/vaquarkhan/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/vaquarkhan/followers',
#    'following_url': 'https://api.github.com/users/vaquarkhan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/vaquarkhan/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/vaquarkhan',
#    'id': 3491908,
#    'login': 'vaquarkhan',
#    'organizations_url': 'https://api.github.com/users/vaquarkhan/orgs',
#    'received_events_url': 'https://api.github.com/users/vaquarkhan/received_events',
#    'repos_url': 'https://api.github.com/users/vaquarkhan/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/vaquarkhan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/vaquarkhan/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/vaquarkhan'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/pulls{/number}',
#   'pushed_at': '2016-12-18T20:28:56Z',
#   'releases_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/releases{/id}',
#   'size': 22829,
#   'ssh_url': 'git@github.com:vaquarkhan/vk-wiki-notes.git',
#   'stargazers_count': 50,
#   'stargazers_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/stargazers',
#   'statuses_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/subscribers',
#   'subscription_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/subscription',
#   'svn_url': 'https://github.com/vaquarkhan/vk-wiki-notes',
#   'tags_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/tags',
#   'teams_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/teams',
#   'trees_url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes/git/trees{/sha}',
#   'updated_at': '2018-03-02T23:19:45Z',
#   'url': 'https://api.github.com/repos/vaquarkhan/vk-wiki-notes',
#   'watchers': 50,
#   'watchers_count': 50},
#  {'archive_url': 'https://api.github.com/repos/rasbt/deep-learning-book/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/rasbt/deep-learning-book/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/rasbt/deep-learning-book/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/rasbt/deep-learning-book/branches{/branch}',
#   'clone_url': 'https://github.com/rasbt/deep-learning-book.git',
#   'collaborators_url': 'https://api.github.com/repos/rasbt/deep-learning-book/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/rasbt/deep-learning-book/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/rasbt/deep-learning-book/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/rasbt/deep-learning-book/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/rasbt/deep-learning-book/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/rasbt/deep-learning-book/contributors',
#   'created_at': '2016-12-18T07:15:40Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/rasbt/deep-learning-book/deployments',
#   'description': 'Repository for "Introduction to Artificial Neural Networks and Deep Learning: A Practical Guide with Applications in Python"',
#   'downloads_url': 'https://api.github.com/repos/rasbt/deep-learning-book/downloads',
#   'events_url': 'https://api.github.com/repos/rasbt/deep-learning-book/events',
#   'fork': False,
#   'forks': 408,
#   'forks_count': 408,
#   'forks_url': 'https://api.github.com/repos/rasbt/deep-learning-book/forks',
#   'full_name': 'rasbt/deep-learning-book',
#   'git_commits_url': 'https://api.github.com/repos/rasbt/deep-learning-book/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/rasbt/deep-learning-book/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/rasbt/deep-learning-book/git/tags{/sha}',
#   'git_url': 'git://github.com/rasbt/deep-learning-book.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/rasbt/deep-learning-book/hooks',
#   'html_url': 'https://github.com/rasbt/deep-learning-book',
#   'id': 76768630,
#   'issue_comment_url': 'https://api.github.com/repos/rasbt/deep-learning-book/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/rasbt/deep-learning-book/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/rasbt/deep-learning-book/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/rasbt/deep-learning-book/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/rasbt/deep-learning-book/labels{/name}',
#   'language': 'Jupyter Notebook',
#   'languages_url': 'https://api.github.com/repos/rasbt/deep-learning-book/languages',
#   'license': {'key': 'other', 'name': 'Other', 'spdx_id': None, 'url': None},
#   'merges_url': 'https://api.github.com/repos/rasbt/deep-learning-book/merges',
#   'milestones_url': 'https://api.github.com/repos/rasbt/deep-learning-book/milestones{/number}',
#   'mirror_url': None,
#   'name': 'deep-learning-book',
#   'notifications_url': 'https://api.github.com/repos/rasbt/deep-learning-book/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars3.githubusercontent.com/u/5618407?v=4',
#    'events_url': 'https://api.github.com/users/rasbt/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/rasbt/followers',
#    'following_url': 'https://api.github.com/users/rasbt/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rasbt/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/rasbt',
#    'id': 5618407,
#    'login': 'rasbt',
#    'organizations_url': 'https://api.github.com/users/rasbt/orgs',
#    'received_events_url': 'https://api.github.com/users/rasbt/received_events',
#    'repos_url': 'https://api.github.com/users/rasbt/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/rasbt/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rasbt/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/rasbt'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/rasbt/deep-learning-book/pulls{/number}',
#   'pushed_at': '2018-03-03T02:24:56Z',
#   'releases_url': 'https://api.github.com/repos/rasbt/deep-learning-book/releases{/id}',
#   'size': 3302,
#   'ssh_url': 'git@github.com:rasbt/deep-learning-book.git',
#   'stargazers_count': 1822,
#   'stargazers_url': 'https://api.github.com/repos/rasbt/deep-learning-book/stargazers',
#   'statuses_url': 'https://api.github.com/repos/rasbt/deep-learning-book/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/rasbt/deep-learning-book/subscribers',
#   'subscription_url': 'https://api.github.com/repos/rasbt/deep-learning-book/subscription',
#   'svn_url': 'https://github.com/rasbt/deep-learning-book',
#   'tags_url': 'https://api.github.com/repos/rasbt/deep-learning-book/tags',
#   'teams_url': 'https://api.github.com/repos/rasbt/deep-learning-book/teams',
#   'trees_url': 'https://api.github.com/repos/rasbt/deep-learning-book/git/trees{/sha}',
#   'updated_at': '2018-03-06T13:45:55Z',
#   'url': 'https://api.github.com/repos/rasbt/deep-learning-book',
#   'watchers': 1822,
#   'watchers_count': 1822},
#  {'archive_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/branches{/branch}',
#   'clone_url': 'https://github.com/arogozhnikov/python3_with_pleasure.git',
#   'collaborators_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/contributors',
#   'created_at': '2017-12-17T14:17:52Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/deployments',
#   'description': 'A short guide on features of Python 3',
#   'downloads_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/downloads',
#   'events_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/events',
#   'fork': False,
#   'forks': 168,
#   'forks_count': 168,
#   'forks_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/forks',
#   'full_name': 'arogozhnikov/python3_with_pleasure',
#   'git_commits_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/git/tags{/sha}',
#   'git_url': 'git://github.com/arogozhnikov/python3_with_pleasure.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': '',
#   'hooks_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/hooks',
#   'html_url': 'https://github.com/arogozhnikov/python3_with_pleasure',
#   'id': 114542075,
#   'issue_comment_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/merges',
#   'milestones_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/milestones{/number}',
#   'mirror_url': None,
#   'name': 'python3_with_pleasure',
#   'notifications_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/notifications{?since,all,participating}',
#   'open_issues': 10,
#   'open_issues_count': 10,
#   'owner': {'avatar_url': 'https://avatars3.githubusercontent.com/u/6318811?v=4',
#    'events_url': 'https://api.github.com/users/arogozhnikov/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/arogozhnikov/followers',
#    'following_url': 'https://api.github.com/users/arogozhnikov/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/arogozhnikov/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/arogozhnikov',
#    'id': 6318811,
#    'login': 'arogozhnikov',
#    'organizations_url': 'https://api.github.com/users/arogozhnikov/orgs',
#    'received_events_url': 'https://api.github.com/users/arogozhnikov/received_events',
#    'repos_url': 'https://api.github.com/users/arogozhnikov/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/arogozhnikov/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/arogozhnikov/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/arogozhnikov'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/pulls{/number}',
#   'pushed_at': '2018-03-01T13:18:36Z',
#   'releases_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/releases{/id}',
#   'size': 505,
#   'ssh_url': 'git@github.com:arogozhnikov/python3_with_pleasure.git',
#   'stargazers_count': 3110,
#   'stargazers_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/stargazers',
#   'statuses_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/subscribers',
#   'subscription_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/subscription',
#   'svn_url': 'https://github.com/arogozhnikov/python3_with_pleasure',
#   'tags_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/tags',
#   'teams_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/teams',
#   'trees_url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure/git/trees{/sha}',
#   'updated_at': '2018-03-06T15:12:30Z',
#   'url': 'https://api.github.com/repos/arogozhnikov/python3_with_pleasure',
#   'watchers': 3110,
#   'watchers_count': 3110},
#  {'archive_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/branches{/branch}',
#   'clone_url': 'https://github.com/masterlittle/SparkmediumAnalysis.git',
#   'collaborators_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/contributors',
#   'created_at': '2017-12-25T18:11:02Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/deployments',
#   'description': 'Analysis of Medium articles. Primarily difference between Popular and Non-Popular articles.',
#   'downloads_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/downloads',
#   'events_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/events',
#   'fork': False,
#   'forks': 2,
#   'forks_count': 2,
#   'forks_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/forks',
#   'full_name': 'masterlittle/SparkmediumAnalysis',
#   'git_commits_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/git/tags{/sha}',
#   'git_url': 'git://github.com/masterlittle/SparkmediumAnalysis.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/hooks',
#   'html_url': 'https://github.com/masterlittle/SparkmediumAnalysis',
#   'id': 115355551,
#   'issue_comment_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/labels{/name}',
#   'language': 'Scala',
#   'languages_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/languages',
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0'},
#   'merges_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/merges',
#   'milestones_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/milestones{/number}',
#   'mirror_url': None,
#   'name': 'SparkmediumAnalysis',
#   'notifications_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars0.githubusercontent.com/u/13149023?v=4',
#    'events_url': 'https://api.github.com/users/masterlittle/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/masterlittle/followers',
#    'following_url': 'https://api.github.com/users/masterlittle/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/masterlittle/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/masterlittle',
#    'id': 13149023,
#    'login': 'masterlittle',
#    'organizations_url': 'https://api.github.com/users/masterlittle/orgs',
#    'received_events_url': 'https://api.github.com/users/masterlittle/received_events',
#    'repos_url': 'https://api.github.com/users/masterlittle/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/masterlittle/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/masterlittle/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/masterlittle'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/pulls{/number}',
#   'pushed_at': '2017-12-25T18:14:01Z',
#   'releases_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/releases{/id}',
#   'size': 1663,
#   'ssh_url': 'git@github.com:masterlittle/SparkmediumAnalysis.git',
#   'stargazers_count': 3,
#   'stargazers_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/stargazers',
#   'statuses_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/subscribers',
#   'subscription_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/subscription',
#   'svn_url': 'https://github.com/masterlittle/SparkmediumAnalysis',
#   'tags_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/tags',
#   'teams_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/teams',
#   'trees_url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis/git/trees{/sha}',
#   'updated_at': '2018-01-21T23:12:14Z',
#   'url': 'https://api.github.com/repos/masterlittle/SparkmediumAnalysis',
#   'watchers': 3,
#   'watchers_count': 3},
#  {'archive_url': 'https://api.github.com/repos/pydata/pandas-datareader/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/pydata/pandas-datareader/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/pydata/pandas-datareader/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/pydata/pandas-datareader/branches{/branch}',
#   'clone_url': 'https://github.com/pydata/pandas-datareader.git',
#   'collaborators_url': 'https://api.github.com/repos/pydata/pandas-datareader/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/pydata/pandas-datareader/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/pydata/pandas-datareader/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/pydata/pandas-datareader/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/pydata/pandas-datareader/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/pydata/pandas-datareader/contributors',
#   'created_at': '2015-01-15T00:34:19Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/pydata/pandas-datareader/deployments',
#   'description': 'Extract data from a wide range of Internet sources into a pandas DataFrame.',
#   'downloads_url': 'https://api.github.com/repos/pydata/pandas-datareader/downloads',
#   'events_url': 'https://api.github.com/repos/pydata/pandas-datareader/events',
#   'fork': False,
#   'forks': 229,
#   'forks_count': 229,
#   'forks_url': 'https://api.github.com/repos/pydata/pandas-datareader/forks',
#   'full_name': 'pydata/pandas-datareader',
#   'git_commits_url': 'https://api.github.com/repos/pydata/pandas-datareader/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/pydata/pandas-datareader/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/pydata/pandas-datareader/git/tags{/sha}',
#   'git_url': 'git://github.com/pydata/pandas-datareader.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': True,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': 'https://pydata.github.io/pandas-datareader/stable/index.html',
#   'hooks_url': 'https://api.github.com/repos/pydata/pandas-datareader/hooks',
#   'html_url': 'https://github.com/pydata/pandas-datareader',
#   'id': 29273084,
#   'issue_comment_url': 'https://api.github.com/repos/pydata/pandas-datareader/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/pydata/pandas-datareader/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/pydata/pandas-datareader/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/pydata/pandas-datareader/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/pydata/pandas-datareader/labels{/name}',
#   'language': 'HTML',
#   'languages_url': 'https://api.github.com/repos/pydata/pandas-datareader/languages',
#   'license': {'key': 'other', 'name': 'Other', 'spdx_id': None, 'url': None},
#   'merges_url': 'https://api.github.com/repos/pydata/pandas-datareader/merges',
#   'milestones_url': 'https://api.github.com/repos/pydata/pandas-datareader/milestones{/number}',
#   'mirror_url': None,
#   'name': 'pandas-datareader',
#   'notifications_url': 'https://api.github.com/repos/pydata/pandas-datareader/notifications{?since,all,participating}',
#   'open_issues': 46,
#   'open_issues_count': 46,
#   'owner': {'avatar_url': 'https://avatars0.githubusercontent.com/u/1284191?v=4',
#    'events_url': 'https://api.github.com/users/pydata/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/pydata/followers',
#    'following_url': 'https://api.github.com/users/pydata/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/pydata/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/pydata',
#    'id': 1284191,
#    'login': 'pydata',
#    'organizations_url': 'https://api.github.com/users/pydata/orgs',
#    'received_events_url': 'https://api.github.com/users/pydata/received_events',
#    'repos_url': 'https://api.github.com/users/pydata/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/pydata/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/pydata/subscriptions',
#    'type': 'Organization',
#    'url': 'https://api.github.com/users/pydata'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/pydata/pandas-datareader/pulls{/number}',
#   'pushed_at': '2018-03-04T17:33:50Z',
#   'releases_url': 'https://api.github.com/repos/pydata/pandas-datareader/releases{/id}',
#   'size': 2488,
#   'ssh_url': 'git@github.com:pydata/pandas-datareader.git',
#   'stargazers_count': 575,
#   'stargazers_url': 'https://api.github.com/repos/pydata/pandas-datareader/stargazers',
#   'statuses_url': 'https://api.github.com/repos/pydata/pandas-datareader/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/pydata/pandas-datareader/subscribers',
#   'subscription_url': 'https://api.github.com/repos/pydata/pandas-datareader/subscription',
#   'svn_url': 'https://github.com/pydata/pandas-datareader',
#   'tags_url': 'https://api.github.com/repos/pydata/pandas-datareader/tags',
#   'teams_url': 'https://api.github.com/repos/pydata/pandas-datareader/teams',
#   'trees_url': 'https://api.github.com/repos/pydata/pandas-datareader/git/trees{/sha}',
#   'updated_at': '2018-03-04T04:01:33Z',
#   'url': 'https://api.github.com/repos/pydata/pandas-datareader',
#   'watchers': 575,
#   'watchers_count': 575},
#  {'archive_url': 'https://api.github.com/repos/kren1/tosheets/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/kren1/tosheets/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/kren1/tosheets/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/kren1/tosheets/branches{/branch}',
#   'clone_url': 'https://github.com/kren1/tosheets.git',
#   'collaborators_url': 'https://api.github.com/repos/kren1/tosheets/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/kren1/tosheets/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/kren1/tosheets/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/kren1/tosheets/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/kren1/tosheets/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/kren1/tosheets/contributors',
#   'created_at': '2017-11-15T14:02:04Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/kren1/tosheets/deployments',
#   'description': 'Send your stdin to google sheets',
#   'downloads_url': 'https://api.github.com/repos/kren1/tosheets/downloads',
#   'events_url': 'https://api.github.com/repos/kren1/tosheets/events',
#   'fork': False,
#   'forks': 19,
#   'forks_count': 19,
#   'forks_url': 'https://api.github.com/repos/kren1/tosheets/forks',
#   'full_name': 'kren1/tosheets',
#   'git_commits_url': 'https://api.github.com/repos/kren1/tosheets/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/kren1/tosheets/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/kren1/tosheets/git/tags{/sha}',
#   'git_url': 'git://github.com/kren1/tosheets.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/kren1/tosheets/hooks',
#   'html_url': 'https://github.com/kren1/tosheets',
#   'id': 110840840,
#   'issue_comment_url': 'https://api.github.com/repos/kren1/tosheets/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/kren1/tosheets/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/kren1/tosheets/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/kren1/tosheets/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/kren1/tosheets/labels{/name}',
#   'language': 'Python',
#   'languages_url': 'https://api.github.com/repos/kren1/tosheets/languages',
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit'},
#   'merges_url': 'https://api.github.com/repos/kren1/tosheets/merges',
#   'milestones_url': 'https://api.github.com/repos/kren1/tosheets/milestones{/number}',
#   'mirror_url': None,
#   'name': 'tosheets',
#   'notifications_url': 'https://api.github.com/repos/kren1/tosheets/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars3.githubusercontent.com/u/310855?v=4',
#    'events_url': 'https://api.github.com/users/kren1/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/kren1/followers',
#    'following_url': 'https://api.github.com/users/kren1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kren1/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/kren1',
#    'id': 310855,
#    'login': 'kren1',
#    'organizations_url': 'https://api.github.com/users/kren1/orgs',
#    'received_events_url': 'https://api.github.com/users/kren1/received_events',
#    'repos_url': 'https://api.github.com/users/kren1/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/kren1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kren1/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/kren1'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/kren1/tosheets/pulls{/number}',
#   'pushed_at': '2018-01-18T11:11:34Z',
#   'releases_url': 'https://api.github.com/repos/kren1/tosheets/releases{/id}',
#   'size': 16,
#   'ssh_url': 'git@github.com:kren1/tosheets.git',
#   'stargazers_count': 502,
#   'stargazers_url': 'https://api.github.com/repos/kren1/tosheets/stargazers',
#   'statuses_url': 'https://api.github.com/repos/kren1/tosheets/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/kren1/tosheets/subscribers',
#   'subscription_url': 'https://api.github.com/repos/kren1/tosheets/subscription',
#   'svn_url': 'https://github.com/kren1/tosheets',
#   'tags_url': 'https://api.github.com/repos/kren1/tosheets/tags',
#   'teams_url': 'https://api.github.com/repos/kren1/tosheets/teams',
#   'trees_url': 'https://api.github.com/repos/kren1/tosheets/git/trees{/sha}',
#   'updated_at': '2018-03-03T16:52:33Z',
#   'url': 'https://api.github.com/repos/kren1/tosheets',
#   'watchers': 502,
#   'watchers_count': 502},
#  {'archive_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/branches{/branch}',
#   'clone_url': 'https://github.com/JohnSnowLabs/spark-nlp.git',
#   'collaborators_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/contributors',
#   'created_at': '2017-09-24T19:36:44Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/deployments',
#   'description': 'Natural Language Understanding Library for Apache Spark.',
#   'downloads_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/downloads',
#   'events_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/events',
#   'fork': False,
#   'forks': 64,
#   'forks_count': 64,
#   'forks_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/forks',
#   'full_name': 'JohnSnowLabs/spark-nlp',
#   'git_commits_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/git/tags{/sha}',
#   'git_url': 'git://github.com/JohnSnowLabs/spark-nlp.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': True,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/hooks',
#   'html_url': 'https://github.com/JohnSnowLabs/spark-nlp',
#   'id': 104670986,
#   'issue_comment_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/labels{/name}',
#   'language': 'Scala',
#   'languages_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/languages',
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0'},
#   'merges_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/merges',
#   'milestones_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/milestones{/number}',
#   'mirror_url': None,
#   'name': 'spark-nlp',
#   'notifications_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/notifications{?since,all,participating}',
#   'open_issues': 29,
#   'open_issues_count': 29,
#   'owner': {'avatar_url': 'https://avatars0.githubusercontent.com/u/15903364?v=4',
#    'events_url': 'https://api.github.com/users/JohnSnowLabs/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/JohnSnowLabs/followers',
#    'following_url': 'https://api.github.com/users/JohnSnowLabs/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/JohnSnowLabs/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/JohnSnowLabs',
#    'id': 15903364,
#    'login': 'JohnSnowLabs',
#    'organizations_url': 'https://api.github.com/users/JohnSnowLabs/orgs',
#    'received_events_url': 'https://api.github.com/users/JohnSnowLabs/received_events',
#    'repos_url': 'https://api.github.com/users/JohnSnowLabs/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/JohnSnowLabs/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/JohnSnowLabs/subscriptions',
#    'type': 'Organization',
#    'url': 'https://api.github.com/users/JohnSnowLabs'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/pulls{/number}',
#   'pushed_at': '2018-03-06T12:50:15Z',
#   'releases_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/releases{/id}',
#   'size': 136747,
#   'ssh_url': 'git@github.com:JohnSnowLabs/spark-nlp.git',
#   'stargazers_count': 265,
#   'stargazers_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/stargazers',
#   'statuses_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/subscribers',
#   'subscription_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/subscription',
#   'svn_url': 'https://github.com/JohnSnowLabs/spark-nlp',
#   'tags_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/tags',
#   'teams_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/teams',
#   'trees_url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp/git/trees{/sha}',
#   'updated_at': '2018-03-06T16:00:40Z',
#   'url': 'https://api.github.com/repos/JohnSnowLabs/spark-nlp',
#   'watchers': 265,
#   'watchers_count': 265},
#  {'archive_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/branches{/branch}',
#   'clone_url': 'https://github.com/learnbyexample/Command-line-text-processing.git',
#   'collaborators_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/contributors',
#   'created_at': '2017-03-25T04:38:11Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/deployments',
#   'description': ':zap: From finding text to search and replace, from sorting to beautifying text and more :art:',
#   'downloads_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/downloads',
#   'events_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/events',
#   'fork': False,
#   'forks': 341,
#   'forks_count': 341,
#   'forks_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/forks',
#   'full_name': 'learnbyexample/Command-line-text-processing',
#   'git_commits_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/git/tags{/sha}',
#   'git_url': 'git://github.com/learnbyexample/Command-line-text-processing.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': '',
#   'hooks_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/hooks',
#   'html_url': 'https://github.com/learnbyexample/Command-line-text-processing',
#   'id': 86132832,
#   'issue_comment_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/labels{/name}',
#   'language': 'Shell',
#   'languages_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/merges',
#   'milestones_url': 'https://api.github.com/repos/learnbyexample/Command-line-text-processing/milestones{/number}',
#   'mirror_url': None,
#   'name': 'Command-line-text-processing',
# ...
#   'blobs_url': 'https://api.github.com/repos/vivekn/autocomplete/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/vivekn/autocomplete/branches{/branch}',
#   'clone_url': 'https://github.com/vivekn/autocomplete.git',
#   'collaborators_url': 'https://api.github.com/repos/vivekn/autocomplete/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/vivekn/autocomplete/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/vivekn/autocomplete/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/vivekn/autocomplete/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/vivekn/autocomplete/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/vivekn/autocomplete/contributors',
#   'created_at': '2012-02-25T06:24:23Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/vivekn/autocomplete/deployments',
#   'description': 'Tries for efficient automatic word completion in Python, C++, Ruby & Java.',
#   'downloads_url': 'https://api.github.com/repos/vivekn/autocomplete/downloads',
#   'events_url': 'https://api.github.com/repos/vivekn/autocomplete/events',
#   'fork': False,
#   'forks': 30,
#   'forks_count': 30,
#   'forks_url': 'https://api.github.com/repos/vivekn/autocomplete/forks',
#   'full_name': 'vivekn/autocomplete',
#   'git_commits_url': 'https://api.github.com/repos/vivekn/autocomplete/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/vivekn/autocomplete/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/vivekn/autocomplete/git/tags{/sha}',
#   'git_url': 'git://github.com/vivekn/autocomplete.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': '',
#   'hooks_url': 'https://api.github.com/repos/vivekn/autocomplete/hooks',
#   'html_url': 'https://github.com/vivekn/autocomplete',
#   'id': 3542878,
#   'issue_comment_url': 'https://api.github.com/repos/vivekn/autocomplete/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/vivekn/autocomplete/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/vivekn/autocomplete/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/vivekn/autocomplete/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/vivekn/autocomplete/labels{/name}',
#   'language': 'Scala',
#   'languages_url': 'https://api.github.com/repos/vivekn/autocomplete/languages',
#   'license': {'key': 'bsd-2-clause',
#    'name': 'BSD 2-Clause "Simplified" License',
#    'spdx_id': 'BSD-2-Clause',
#    'url': 'https://api.github.com/licenses/bsd-2-clause'},
#   'merges_url': 'https://api.github.com/repos/vivekn/autocomplete/merges',
#   'milestones_url': 'https://api.github.com/repos/vivekn/autocomplete/milestones{/number}',
#   'mirror_url': None,
#   'name': 'autocomplete',
#   'notifications_url': 'https://api.github.com/repos/vivekn/autocomplete/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars1.githubusercontent.com/u/380627?v=4',
#    'events_url': 'https://api.github.com/users/vivekn/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/vivekn/followers',
#    'following_url': 'https://api.github.com/users/vivekn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/vivekn/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/vivekn',
#    'id': 380627,
#    'login': 'vivekn',
#    'organizations_url': 'https://api.github.com/users/vivekn/orgs',
#    'received_events_url': 'https://api.github.com/users/vivekn/received_events',
#    'repos_url': 'https://api.github.com/users/vivekn/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/vivekn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/vivekn/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/vivekn'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/vivekn/autocomplete/pulls{/number}',
#   'pushed_at': '2015-04-16T11:24:59Z',
#   'releases_url': 'https://api.github.com/repos/vivekn/autocomplete/releases{/id}',
#   'size': 998,
#   'ssh_url': 'git@github.com:vivekn/autocomplete.git',
#   'stargazers_count': 105,
#   'stargazers_url': 'https://api.github.com/repos/vivekn/autocomplete/stargazers',
#   'statuses_url': 'https://api.github.com/repos/vivekn/autocomplete/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/vivekn/autocomplete/subscribers',
#   'subscription_url': 'https://api.github.com/repos/vivekn/autocomplete/subscription',
#   'svn_url': 'https://github.com/vivekn/autocomplete',
#   'tags_url': 'https://api.github.com/repos/vivekn/autocomplete/tags',
#   'teams_url': 'https://api.github.com/repos/vivekn/autocomplete/teams',
#   'trees_url': 'https://api.github.com/repos/vivekn/autocomplete/git/trees{/sha}',
#   'updated_at': '2018-02-28T06:58:52Z',
#   'url': 'https://api.github.com/repos/vivekn/autocomplete',
#   'watchers': 105,
#   'watchers_count': 105},
#  {'archive_url': 'https://api.github.com/repos/jundongl/scikit-feature/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/jundongl/scikit-feature/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/jundongl/scikit-feature/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/jundongl/scikit-feature/branches{/branch}',
#   'clone_url': 'https://github.com/jundongl/scikit-feature.git',
#   'collaborators_url': 'https://api.github.com/repos/jundongl/scikit-feature/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/jundongl/scikit-feature/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/jundongl/scikit-feature/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/jundongl/scikit-feature/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/jundongl/scikit-feature/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/jundongl/scikit-feature/contributors',
#   'created_at': '2015-11-06T16:34:33Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/jundongl/scikit-feature/deployments',
#   'description': 'open-source feature selection repository in python (DMML Lab@ASU)',
#   'downloads_url': 'https://api.github.com/repos/jundongl/scikit-feature/downloads',
#   'events_url': 'https://api.github.com/repos/jundongl/scikit-feature/events',
#   'fork': False,
#   'forks': 138,
#   'forks_count': 138,
#   'forks_url': 'https://api.github.com/repos/jundongl/scikit-feature/forks',
#   'full_name': 'jundongl/scikit-feature',
#   'git_commits_url': 'https://api.github.com/repos/jundongl/scikit-feature/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/jundongl/scikit-feature/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/jundongl/scikit-feature/git/tags{/sha}',
#   'git_url': 'git://github.com/jundongl/scikit-feature.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': 'http://featureselection.asu.edu/',
#   'hooks_url': 'https://api.github.com/repos/jundongl/scikit-feature/hooks',
#   'html_url': 'https://github.com/jundongl/scikit-feature',
#   'id': 45693656,
#   'issue_comment_url': 'https://api.github.com/repos/jundongl/scikit-feature/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/jundongl/scikit-feature/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/jundongl/scikit-feature/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/jundongl/scikit-feature/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/jundongl/scikit-feature/labels{/name}',
#   'language': 'Python',
#   'languages_url': 'https://api.github.com/repos/jundongl/scikit-feature/languages',
#   'license': {'key': 'gpl-2.0',
#    'name': 'GNU General Public License v2.0',
#    'spdx_id': 'GPL-2.0',
#    'url': 'https://api.github.com/licenses/gpl-2.0'},
#   'merges_url': 'https://api.github.com/repos/jundongl/scikit-feature/merges',
#   'milestones_url': 'https://api.github.com/repos/jundongl/scikit-feature/milestones{/number}',
#   'mirror_url': None,
#   'name': 'scikit-feature',
#   'notifications_url': 'https://api.github.com/repos/jundongl/scikit-feature/notifications{?since,all,participating}',
#   'open_issues': 6,
#   'open_issues_count': 6,
#   'owner': {'avatar_url': 'https://avatars3.githubusercontent.com/u/10163779?v=4',
#    'events_url': 'https://api.github.com/users/jundongl/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/jundongl/followers',
#    'following_url': 'https://api.github.com/users/jundongl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jundongl/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/jundongl',
#    'id': 10163779,
#    'login': 'jundongl',
#    'organizations_url': 'https://api.github.com/users/jundongl/orgs',
#    'received_events_url': 'https://api.github.com/users/jundongl/received_events',
#    'repos_url': 'https://api.github.com/users/jundongl/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/jundongl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jundongl/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/jundongl'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/jundongl/scikit-feature/pulls{/number}',
#   'pushed_at': '2017-11-30T21:12:16Z',
#   'releases_url': 'https://api.github.com/repos/jundongl/scikit-feature/releases{/id}',
#   'size': 125104,
#   'ssh_url': 'git@github.com:jundongl/scikit-feature.git',
#   'stargazers_count': 506,
#   'stargazers_url': 'https://api.github.com/repos/jundongl/scikit-feature/stargazers',
#   'statuses_url': 'https://api.github.com/repos/jundongl/scikit-feature/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/jundongl/scikit-feature/subscribers',
#   'subscription_url': 'https://api.github.com/repos/jundongl/scikit-feature/subscription',
#   'svn_url': 'https://github.com/jundongl/scikit-feature',
#   'tags_url': 'https://api.github.com/repos/jundongl/scikit-feature/tags',
#   'teams_url': 'https://api.github.com/repos/jundongl/scikit-feature/teams',
#   'trees_url': 'https://api.github.com/repos/jundongl/scikit-feature/git/trees{/sha}',
#   'updated_at': '2018-03-05T19:51:40Z',
#   'url': 'https://api.github.com/repos/jundongl/scikit-feature',
#   'watchers': 506,
#   'watchers_count': 506},
#  {'archive_url': 'https://api.github.com/repos/reiinakano/scikit-plot/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/reiinakano/scikit-plot/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/reiinakano/scikit-plot/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/reiinakano/scikit-plot/branches{/branch}',
#   'clone_url': 'https://github.com/reiinakano/scikit-plot.git',
#   'collaborators_url': 'https://api.github.com/repos/reiinakano/scikit-plot/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/reiinakano/scikit-plot/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/reiinakano/scikit-plot/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/reiinakano/scikit-plot/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/reiinakano/scikit-plot/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/reiinakano/scikit-plot/contributors',
#   'created_at': '2017-02-04T06:22:59Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/reiinakano/scikit-plot/deployments',
#   'description': 'An intuitive library to add plotting functionality to scikit-learn objects.',
#   'downloads_url': 'https://api.github.com/repos/reiinakano/scikit-plot/downloads',
#   'events_url': 'https://api.github.com/repos/reiinakano/scikit-plot/events',
#   'fork': False,
#   'forks': 102,
#   'forks_count': 102,
#   'forks_url': 'https://api.github.com/repos/reiinakano/scikit-plot/forks',
#   'full_name': 'reiinakano/scikit-plot',
#   'git_commits_url': 'https://api.github.com/repos/reiinakano/scikit-plot/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/reiinakano/scikit-plot/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/reiinakano/scikit-plot/git/tags{/sha}',
#   'git_url': 'git://github.com/reiinakano/scikit-plot.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': '',
#   'hooks_url': 'https://api.github.com/repos/reiinakano/scikit-plot/hooks',
#   'html_url': 'https://github.com/reiinakano/scikit-plot',
#   'id': 80898688,
#   'issue_comment_url': 'https://api.github.com/repos/reiinakano/scikit-plot/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/reiinakano/scikit-plot/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/reiinakano/scikit-plot/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/reiinakano/scikit-plot/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/reiinakano/scikit-plot/labels{/name}',
#   'language': 'Python',
#   'languages_url': 'https://api.github.com/repos/reiinakano/scikit-plot/languages',
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit'},
#   'merges_url': 'https://api.github.com/repos/reiinakano/scikit-plot/merges',
#   'milestones_url': 'https://api.github.com/repos/reiinakano/scikit-plot/milestones{/number}',
#   'mirror_url': None,
#   'name': 'scikit-plot',
#   'notifications_url': 'https://api.github.com/repos/reiinakano/scikit-plot/notifications{?since,all,participating}',
#   'open_issues': 7,
#   'open_issues_count': 7,
#   'owner': {'avatar_url': 'https://avatars0.githubusercontent.com/u/18363734?v=4',
#    'events_url': 'https://api.github.com/users/reiinakano/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/reiinakano/followers',
#    'following_url': 'https://api.github.com/users/reiinakano/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/reiinakano/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/reiinakano',
#    'id': 18363734,
#    'login': 'reiinakano',
#    'organizations_url': 'https://api.github.com/users/reiinakano/orgs',
#    'received_events_url': 'https://api.github.com/users/reiinakano/received_events',
#    'repos_url': 'https://api.github.com/users/reiinakano/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/reiinakano/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/reiinakano/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/reiinakano'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/reiinakano/scikit-plot/pulls{/number}',
#   'pushed_at': '2018-03-05T01:47:54Z',
#   'releases_url': 'https://api.github.com/repos/reiinakano/scikit-plot/releases{/id}',
#   'size': 3073,
#   'ssh_url': 'git@github.com:reiinakano/scikit-plot.git',
#   'stargazers_count': 1082,
#   'stargazers_url': 'https://api.github.com/repos/reiinakano/scikit-plot/stargazers',
#   'statuses_url': 'https://api.github.com/repos/reiinakano/scikit-plot/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/reiinakano/scikit-plot/subscribers',
#   'subscription_url': 'https://api.github.com/repos/reiinakano/scikit-plot/subscription',
#   'svn_url': 'https://github.com/reiinakano/scikit-plot',
#   'tags_url': 'https://api.github.com/repos/reiinakano/scikit-plot/tags',
#   'teams_url': 'https://api.github.com/repos/reiinakano/scikit-plot/teams',
#   'trees_url': 'https://api.github.com/repos/reiinakano/scikit-plot/git/trees{/sha}',
#   'updated_at': '2018-03-06T13:52:57Z',
#   'url': 'https://api.github.com/repos/reiinakano/scikit-plot',
#   'watchers': 1082,
#   'watchers_count': 1082}]

# %%
import os 
import pandas as pd
import requests
PATH=r'C:/Users/Administrator/Desktop/'
r=requests.get('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')
with open(PATH+'iris.data','w') as f:
    f.write(r.text)
os.chdir(PATH)
df=pd.read_csv(PATH+'iris.data',names=['sepal length','sepal width','petal length','petal width','class'])
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df['sepal length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
# 5      5.4
# 6      4.6
# 7      5.0
# 8      4.4
# 9      4.9
# 10     5.4
# 11     4.8
# 12     4.8
# 13     4.3
# 14     5.8
# 15     5.7
# 16     5.4
# 17     5.1
# 18     5.7
# 19     5.1
# 20     5.4
# 21     5.1
# 22     4.6
# 23     5.1
# 24     4.8
# 25     5.0
# 26     5.0
# 27     5.2
# 28     5.2
# 29     4.7
#       ...
# 120    6.9
# 121    5.6
# 122    7.7
# 123    6.3
# 124    6.7
# 125    7.2
# 126    6.2
# 127    6.1
# 128    6.4
# 129    7.2
# 130    7.4
# 131    7.9
# 132    6.4
# 133    6.3
# 134    6.1
# 135    7.7
# 136    6.3
# 137    6.4
# 138    6.0
# 139    6.9
# 140    6.7
# 141    6.9
# 142    5.8
# 143    6.8
# 144    6.7
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal length, Length: 150, dtype: float64

# %%
df.ix[:3,:2]
# Out:
#    sepal length  sepal width
# 0           5.1          3.5
# 1           4.9          3.0
# 2           4.7          3.2
# 3           4.6          3.1

# %%
df.ix[:3,[x for x in df.columns if 'width' in x]]
# Out:
#    sepal width  petal width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2

# %%
df['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df[df['class']=='Iris-virginica']
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 101           5.8          2.7           5.1          1.9  Iris-virginica
# 102           7.1          3.0           5.9          2.1  Iris-virginica
# 103           6.3          2.9           5.6          1.8  Iris-virginica
# 104           6.5          3.0           5.8          2.2  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 106           4.9          2.5           4.5          1.7  Iris-virginica
# 107           7.3          2.9           6.3          1.8  Iris-virginica
# 108           6.7          2.5           5.8          1.8  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
# 110           6.5          3.2           5.1          2.0  Iris-virginica
# 111           6.4          2.7           5.3          1.9  Iris-virginica
# 112           6.8          3.0           5.5          2.1  Iris-virginica
# 113           5.7          2.5           5.0          2.0  Iris-virginica
# 114           5.8          2.8           5.1          2.4  Iris-virginica
# 115           6.4          3.2           5.3          2.3  Iris-virginica
# 116           6.5          3.0           5.5          1.8  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 119           6.0          2.2           5.0          1.5  Iris-virginica
# 120           6.9          3.2           5.7          2.3  Iris-virginica
# 121           5.6          2.8           4.9          2.0  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 123           6.3          2.7           4.9          1.8  Iris-virginica
# 124           6.7          3.3           5.7          2.1  Iris-virginica
# 125           7.2          3.2           6.0          1.8  Iris-virginica
# 126           6.2          2.8           4.8          1.8  Iris-virginica
# 127           6.1          3.0           4.9          1.8  Iris-virginica
# 128           6.4          2.8           5.6          2.1  Iris-virginica
# 129           7.2          3.0           5.8          1.6  Iris-virginica
# 130           7.4          2.8           6.1          1.9  Iris-virginica
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# 132           6.4          2.8           5.6          2.2  Iris-virginica
# 133           6.3          2.8           5.1          1.5  Iris-virginica
# 134           6.1          2.6           5.6          1.4  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 136           6.3          3.4           5.6          2.4  Iris-virginica
# 137           6.4          3.1           5.5          1.8  Iris-virginica
# 138           6.0          3.0           4.8          1.8  Iris-virginica
# 139           6.9          3.1           5.4          2.1  Iris-virginica
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 141           6.9          3.1           5.1          2.3  Iris-virginica
# 142           5.8          2.7           5.1          1.9  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.count()
# Out:
# sepal length    150
# sepal width     150
# petal length    150
# petal width     150
# class           150
# dtype: int64

# %%
df[df['class']=='Iris-virginica'].count()
# Out:
# sepal length    50
# sepal width     50
# petal length    50
# petal width     50
# class           50
# dtype: int64

# %%
virginica=df[df['class']=='Iris-virginica'].reset_index(drop=True)
virginica
# Out:
#     sepal length  sepal width  petal length  petal width           class
# 0            6.3          3.3           6.0          2.5  Iris-virginica
# 1            5.8          2.7           5.1          1.9  Iris-virginica
# 2            7.1          3.0           5.9          2.1  Iris-virginica
# 3            6.3          2.9           5.6          1.8  Iris-virginica
# 4            6.5          3.0           5.8          2.2  Iris-virginica
# 5            7.6          3.0           6.6          2.1  Iris-virginica
# 6            4.9          2.5           4.5          1.7  Iris-virginica
# 7            7.3          2.9           6.3          1.8  Iris-virginica
# 8            6.7          2.5           5.8          1.8  Iris-virginica
# 9            7.2          3.6           6.1          2.5  Iris-virginica
# 10           6.5          3.2           5.1          2.0  Iris-virginica
# 11           6.4          2.7           5.3          1.9  Iris-virginica
# 12           6.8          3.0           5.5          2.1  Iris-virginica
# 13           5.7          2.5           5.0          2.0  Iris-virginica
# 14           5.8          2.8           5.1          2.4  Iris-virginica
# 15           6.4          3.2           5.3          2.3  Iris-virginica
# 16           6.5          3.0           5.5          1.8  Iris-virginica
# 17           7.7          3.8           6.7          2.2  Iris-virginica
# 18           7.7          2.6           6.9          2.3  Iris-virginica
# 19           6.0          2.2           5.0          1.5  Iris-virginica
# 20           6.9          3.2           5.7          2.3  Iris-virginica
# 21           5.6          2.8           4.9          2.0  Iris-virginica
# 22           7.7          2.8           6.7          2.0  Iris-virginica
# 23           6.3          2.7           4.9          1.8  Iris-virginica
# 24           6.7          3.3           5.7          2.1  Iris-virginica
# 25           7.2          3.2           6.0          1.8  Iris-virginica
# 26           6.2          2.8           4.8          1.8  Iris-virginica
# 27           6.1          3.0           4.9          1.8  Iris-virginica
# 28           6.4          2.8           5.6          2.1  Iris-virginica
# 29           7.2          3.0           5.8          1.6  Iris-virginica
# 30           7.4          2.8           6.1          1.9  Iris-virginica
# 31           7.9          3.8           6.4          2.0  Iris-virginica
# 32           6.4          2.8           5.6          2.2  Iris-virginica
# 33           6.3          2.8           5.1          1.5  Iris-virginica
# 34           6.1          2.6           5.6          1.4  Iris-virginica
# 35           7.7          3.0           6.1          2.3  Iris-virginica
# 36           6.3          3.4           5.6          2.4  Iris-virginica
# 37           6.4          3.1           5.5          1.8  Iris-virginica
# 38           6.0          3.0           4.8          1.8  Iris-virginica
# 39           6.9          3.1           5.4          2.1  Iris-virginica
# 40           6.7          3.1           5.6          2.4  Iris-virginica
# 41           6.9          3.1           5.1          2.3  Iris-virginica
# 42           5.8          2.7           5.1          1.9  Iris-virginica
# 43           6.8          3.2           5.9          2.3  Iris-virginica
# 44           6.7          3.3           5.7          2.5  Iris-virginica
# 45           6.7          3.0           5.2          2.3  Iris-virginica
# 46           6.3          2.5           5.0          1.9  Iris-virginica
# 47           6.5          3.0           5.2          2.0  Iris-virginica
# 48           6.2          3.4           5.4          2.3  Iris-virginica
# 49           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df[(df['class']=='Iris-virginica')&(df['petal width']>2.2)]
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
# 114           5.8          2.8           5.1          2.4  Iris-virginica
# 115           6.4          3.2           5.3          2.3  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 120           6.9          3.2           5.7          2.3  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 136           6.3          3.4           5.6          2.4  Iris-virginica
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 141           6.9          3.1           5.1          2.3  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica

# %%
df.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.describe(percentiles=[.20,.40,.80,.90,.95])
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 20%        5.000000     2.700000      1.500000     0.200000
# 40%        5.600000     3.000000      3.900000     1.160000
# 50%        5.800000     3.000000      4.350000     1.300000
# 80%        6.520000     3.400000      5.320000     1.900000
# 90%        6.900000     3.610000      5.800000     2.200000
# 95%        7.255000     3.800000      6.100000     2.300000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.corr()
# Out:
#               sepal length  sepal width  petal length  petal width
# sepal length      1.000000    -0.109369      0.871754     0.817954
# sepal width      -0.109369     1.000000     -0.420516    -0.356544
# petal length      0.871754    -0.420516      1.000000     0.962757
# petal width       0.817954    -0.356544      0.962757     1.000000

# %%
df.corr(method="spearman")
# Out:
#               sepal length  sepal width  petal length  petal width
# sepal length      1.000000    -0.159457      0.881386     0.834421
# sepal width      -0.159457     1.000000     -0.303421    -0.277511
# petal length      0.881386    -0.303421      1.000000     0.936003
# petal width       0.834421    -0.277511      0.936003     1.000000

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline
import numpy as np
fig,ax=plt.subplots(figsize=(6,4))
ax.hist(df['petal width'],color='black');
ax.set_ylabel('Count',fontsize=12)
ax.set_xlabel('Width',fontsize=12)
plt.title('Iris Petal Width',fontsize=14,y=1.01)

# %%
fig, ax = plt.subplots(2,2, figsize=(6,4))

ax[0][0].hist(df['petal width'], color='black');
ax[0][0].set_ylabel('Count', fontsize=12)
ax[0][0].set_xlabel('Width', fontsize=12)
ax[0][0].set_title('Iris Petal Width', fontsize=14, y=1.01)

ax[0][1].hist(df['petal length'], color='black');
ax[0][1].set_ylabel('Count', fontsize=12)
ax[0][1].set_xlabel('Lenth', fontsize=12)
ax[0][1].set_title('Iris Petal Lenth', fontsize=14, y=1.01)

ax[1][0].hist(df['sepal width'], color='black');
ax[1][0].set_ylabel('Count', fontsize=12)
ax[1][0].set_xlabel('Width', fontsize=12)
ax[1][0].set_title('Iris Sepal Width', fontsize=14, y=1.01)

ax[1][1].hist(df['sepal length'], color='black');
ax[1][1].set_ylabel('Count', fontsize=12)
ax[1][1].set_xlabel('Length', fontsize=12)
ax[1][1].set_title('Iris Sepal Length', fontsize=14, y=1.01)

plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(6,6))
ax.scatter(df['petal width'],df['petal length'], color='green')
ax.set_xlabel('Petal Width')
ax.set_ylabel('Petal Length')
ax.set_title('Petal Scatterplot')

# %%
fig, ax = plt.subplots(figsize=(6,6))
ax.plot(df['petal length'], color='blue')
ax.set_xlabel('Specimen Number')
ax.set_ylabel('Petal Length')
ax.set_title('Petal Length Plot')

# %%
fig, ax = plt.subplots(figsize=(6,6))
bar_width = .8
labels = [x for x in df.columns if 'length' in x or 'width' in x]
ver_y = [df[df['class']=='Iris-versicolor'][x].mean() for x in labels]
vir_y = [df[df['class']=='Iris-virginica'][x].mean() for x in labels]
set_y = [df[df['class']=='Iris-setosa'][x].mean() for x in labels]
x = np.arange(len(labels))
ax.bar(x, vir_y, bar_width, bottom=set_y, color='darkgrey')
ax.bar(x, set_y, bar_width, bottom=ver_y, color='white')
ax.bar(x, ver_y, bar_width, color='black')
ax.set_xticks(x + (bar_width/2))
ax.set_xticklabels(labels, rotation=-70, fontsize=12);
ax.set_title('Mean Feature Measurement By Class', y=1.01)
ax.legend(['Virginica','Setosa','Versicolor'])

# %%
import seaborn as sns
sns.pairplot(df, hue="class")

# %%
fig, ax = plt.subplots(2, 2, figsize=(7, 7))
sns.set(style='white', palette='muted')
sns.violinplot(x=df['class'], y=df['sepal length'], ax=ax[0,0])
sns.violinplot(x=df['class'], y=df['sepal width'], ax=ax[0,1])
sns.violinplot(x=df['class'], y=df['petal length'], ax=ax[1,0])
sns.violinplot(x=df['class'], y=df['petal width'], ax=ax[1,1])
fig.suptitle('Violin Plots', fontsize=16, y=1.03)
for i in ax.flat:
    plt.setp(i.get_xticklabels(), rotation=-90)
fig.tight_layout()

# %%
df['class'] = df['class'].map({'Iris-setosa':'SET', 'Iris-virginica': 'VIR', 'Iris-versicolor': 'VER'})
df
# Out:
#      sepal length  sepal width  petal length  petal width class
# 0             5.1          3.5           1.4          0.2   SET
# 1             4.9          3.0           1.4          0.2   SET
# 2             4.7          3.2           1.3          0.2   SET
# 3             4.6          3.1           1.5          0.2   SET
# 4             5.0          3.6           1.4          0.2   SET
# 5             5.4          3.9           1.7          0.4   SET
# 6             4.6          3.4           1.4          0.3   SET
# 7             5.0          3.4           1.5          0.2   SET
# 8             4.4          2.9           1.4          0.2   SET
# 9             4.9          3.1           1.5          0.1   SET
# 10            5.4          3.7           1.5          0.2   SET
# 11            4.8          3.4           1.6          0.2   SET
# 12            4.8          3.0           1.4          0.1   SET
# 13            4.3          3.0           1.1          0.1   SET
# 14            5.8          4.0           1.2          0.2   SET
# 15            5.7          4.4           1.5          0.4   SET
# 16            5.4          3.9           1.3          0.4   SET
# 17            5.1          3.5           1.4          0.3   SET
# 18            5.7          3.8           1.7          0.3   SET
# 19            5.1          3.8           1.5          0.3   SET
# 20            5.4          3.4           1.7          0.2   SET
# 21            5.1          3.7           1.5          0.4   SET
# 22            4.6          3.6           1.0          0.2   SET
# 23            5.1          3.3           1.7          0.5   SET
# 24            4.8          3.4           1.9          0.2   SET
# 25            5.0          3.0           1.6          0.2   SET
# 26            5.0          3.4           1.6          0.4   SET
# 27            5.2          3.5           1.5          0.2   SET
# 28            5.2          3.4           1.4          0.2   SET
# 29            4.7          3.2           1.6          0.2   SET
# ..            ...          ...           ...          ...   ...
# 120           6.9          3.2           5.7          2.3   VIR
# 121           5.6          2.8           4.9          2.0   VIR
# 122           7.7          2.8           6.7          2.0   VIR
# 123           6.3          2.7           4.9          1.8   VIR
# 124           6.7          3.3           5.7          2.1   VIR
# 125           7.2          3.2           6.0          1.8   VIR
# 126           6.2          2.8           4.8          1.8   VIR
# 127           6.1          3.0           4.9          1.8   VIR
# 128           6.4          2.8           5.6          2.1   VIR
# 129           7.2          3.0           5.8          1.6   VIR
# 130           7.4          2.8           6.1          1.9   VIR
# 131           7.9          3.8           6.4          2.0   VIR
# 132           6.4          2.8           5.6          2.2   VIR
# 133           6.3          2.8           5.1          1.5   VIR
# 134           6.1          2.6           5.6          1.4   VIR
# 135           7.7          3.0           6.1          2.3   VIR
# 136           6.3          3.4           5.6          2.4   VIR
# 137           6.4          3.1           5.5          1.8   VIR
# 138           6.0          3.0           4.8          1.8   VIR
# 139           6.9          3.1           5.4          2.1   VIR
# 140           6.7          3.1           5.6          2.4   VIR
# 141           6.9          3.1           5.1          2.3   VIR
# 142           5.8          2.7           5.1          1.9   VIR
# 143           6.8          3.2           5.9          2.3   VIR
# 144           6.7          3.3           5.7          2.5   VIR
# 145           6.7          3.0           5.2          2.3   VIR
# 146           6.3          2.5           5.0          1.9   VIR
# 147           6.5          3.0           5.2          2.0   VIR
# 148           6.2          3.4           5.4          2.3   VIR
# 149           5.9          3.0           5.1          1.8   VIR
#
# [150 rows x 5 columns]

# %%
df['wide petal'] = df['petal width'].apply(lambda v: 1 if v >= 1.3 else 0)
df
# Out:
#      sepal length  sepal width  petal length  petal width class  wide petal
# 0             5.1          3.5           1.4          0.2   SET           0
# 1             4.9          3.0           1.4          0.2   SET           0
# 2             4.7          3.2           1.3          0.2   SET           0
# 3             4.6          3.1           1.5          0.2   SET           0
# 4             5.0          3.6           1.4          0.2   SET           0
# 5             5.4          3.9           1.7          0.4   SET           0
# 6             4.6          3.4           1.4          0.3   SET           0
# 7             5.0          3.4           1.5          0.2   SET           0
# 8             4.4          2.9           1.4          0.2   SET           0
# 9             4.9          3.1           1.5          0.1   SET           0
# 10            5.4          3.7           1.5          0.2   SET           0
# 11            4.8          3.4           1.6          0.2   SET           0
# 12            4.8          3.0           1.4          0.1   SET           0
# 13            4.3          3.0           1.1          0.1   SET           0
# 14            5.8          4.0           1.2          0.2   SET           0
# 15            5.7          4.4           1.5          0.4   SET           0
# 16            5.4          3.9           1.3          0.4   SET           0
# 17            5.1          3.5           1.4          0.3   SET           0
# 18            5.7          3.8           1.7          0.3   SET           0
# 19            5.1          3.8           1.5          0.3   SET           0
# 20            5.4          3.4           1.7          0.2   SET           0
# 21            5.1          3.7           1.5          0.4   SET           0
# 22            4.6          3.6           1.0          0.2   SET           0
# 23            5.1          3.3           1.7          0.5   SET           0
# 24            4.8          3.4           1.9          0.2   SET           0
# 25            5.0          3.0           1.6          0.2   SET           0
# 26            5.0          3.4           1.6          0.4   SET           0
# 27            5.2          3.5           1.5          0.2   SET           0
# 28            5.2          3.4           1.4          0.2   SET           0
# 29            4.7          3.2           1.6          0.2   SET           0
# ..            ...          ...           ...          ...   ...         ...
# 120           6.9          3.2           5.7          2.3   VIR           1
# 121           5.6          2.8           4.9          2.0   VIR           1
# 122           7.7          2.8           6.7          2.0   VIR           1
# 123           6.3          2.7           4.9          1.8   VIR           1
# 124           6.7          3.3           5.7          2.1   VIR           1
# 125           7.2          3.2           6.0          1.8   VIR           1
# 126           6.2          2.8           4.8          1.8   VIR           1
# 127           6.1          3.0           4.9          1.8   VIR           1
# 128           6.4          2.8           5.6          2.1   VIR           1
# 129           7.2          3.0           5.8          1.6   VIR           1
# 130           7.4          2.8           6.1          1.9   VIR           1
# 131           7.9          3.8           6.4          2.0   VIR           1
# 132           6.4          2.8           5.6          2.2   VIR           1
# 133           6.3          2.8           5.1          1.5   VIR           1
# 134           6.1          2.6           5.6          1.4   VIR           1
# 135           7.7          3.0           6.1          2.3   VIR           1
# 136           6.3          3.4           5.6          2.4   VIR           1
# 137           6.4          3.1           5.5          1.8   VIR           1
# 138           6.0          3.0           4.8          1.8   VIR           1
# 139           6.9          3.1           5.4          2.1   VIR           1
# 140           6.7          3.1           5.6          2.4   VIR           1
# 141           6.9          3.1           5.1          2.3   VIR           1
# 142           5.8          2.7           5.1          1.9   VIR           1
# 143           6.8          3.2           5.9          2.3   VIR           1
# 144           6.7          3.3           5.7          2.5   VIR           1
# 145           6.7          3.0           5.2          2.3   VIR           1
# 146           6.3          2.5           5.0          1.9   VIR           1
# 147           6.5          3.0           5.2          2.0   VIR           1
# 148           6.2          3.4           5.4          2.3   VIR           1
# 149           5.9          3.0           5.1          1.8   VIR           1
#
# [150 rows x 6 columns]

# %%
df['petal area'] = df.apply(lambda r: r['petal length'] * r['petal width'], axis=1)
df
# Out:
#      sepal length  sepal width  petal length  petal width class  wide petal  \
# 0             5.1          3.5           1.4          0.2   SET           0
# 1             4.9          3.0           1.4          0.2   SET           0
# 2             4.7          3.2           1.3          0.2   SET           0
# 3             4.6          3.1           1.5          0.2   SET           0
# 4             5.0          3.6           1.4          0.2   SET           0
# 5             5.4          3.9           1.7          0.4   SET           0
# 6             4.6          3.4           1.4          0.3   SET           0
# 7             5.0          3.4           1.5          0.2   SET           0
# 8             4.4          2.9           1.4          0.2   SET           0
# 9             4.9          3.1           1.5          0.1   SET           0
# 10            5.4          3.7           1.5          0.2   SET           0
# 11            4.8          3.4           1.6          0.2   SET           0
# 12            4.8          3.0           1.4          0.1   SET           0
# 13            4.3          3.0           1.1          0.1   SET           0
# 14            5.8          4.0           1.2          0.2   SET           0
# 15            5.7          4.4           1.5          0.4   SET           0
# 16            5.4          3.9           1.3          0.4   SET           0
# 17            5.1          3.5           1.4          0.3   SET           0
# 18            5.7          3.8           1.7          0.3   SET           0
# 19            5.1          3.8           1.5          0.3   SET           0
# 20            5.4          3.4           1.7          0.2   SET           0
# 21            5.1          3.7           1.5          0.4   SET           0
# 22            4.6          3.6           1.0          0.2   SET           0
# 23            5.1          3.3           1.7          0.5   SET           0
# 24            4.8          3.4           1.9          0.2   SET           0
# 25            5.0          3.0           1.6          0.2   SET           0
# 26            5.0          3.4           1.6          0.4   SET           0
# 27            5.2          3.5           1.5          0.2   SET           0
# 28            5.2          3.4           1.4          0.2   SET           0
# 29            4.7          3.2           1.6          0.2   SET           0
# ..            ...          ...           ...          ...   ...         ...
# 120           6.9          3.2           5.7          2.3   VIR           1
# 121           5.6          2.8           4.9          2.0   VIR           1
# 122           7.7          2.8           6.7          2.0   VIR           1
# 123           6.3          2.7           4.9          1.8   VIR           1
# 124           6.7          3.3           5.7          2.1   VIR           1
# 125           7.2          3.2           6.0          1.8   VIR           1
# 126           6.2          2.8           4.8          1.8   VIR           1
# 127           6.1          3.0           4.9          1.8   VIR           1
# 128           6.4          2.8           5.6          2.1   VIR           1
# 129           7.2          3.0           5.8          1.6   VIR           1
# 130           7.4          2.8           6.1          1.9   VIR           1
# 131           7.9          3.8           6.4          2.0   VIR           1
# 132           6.4          2.8           5.6          2.2   VIR           1
# 133           6.3          2.8           5.1          1.5   VIR           1
# 134           6.1          2.6           5.6          1.4   VIR           1
# 135           7.7          3.0           6.1          2.3   VIR           1
# 136           6.3          3.4           5.6          2.4   VIR           1
# 137           6.4          3.1           5.5          1.8   VIR           1
# 138           6.0          3.0           4.8          1.8   VIR           1
# 139           6.9          3.1           5.4          2.1   VIR           1
# 140           6.7          3.1           5.6          2.4   VIR           1
# 141           6.9          3.1           5.1          2.3   VIR           1
# 142           5.8          2.7           5.1          1.9   VIR           1
# 143           6.8          3.2           5.9          2.3   VIR           1
# 144           6.7          3.3           5.7          2.5   VIR           1
# 145           6.7          3.0           5.2          2.3   VIR           1
# 146           6.3          2.5           5.0          1.9   VIR           1
# 147           6.5          3.0           5.2          2.0   VIR           1
# 148           6.2          3.4           5.4          2.3   VIR           1
# 149           5.9          3.0           5.1          1.8   VIR           1
#
#      petal area
# 0          0.28
# 1          0.28
# 2          0.26
# 3          0.30
# 4          0.28
# 5          0.68
# 6          0.42
# 7          0.30
# 8          0.28
# 9          0.15
# 10         0.30
# 11         0.32
# 12         0.14
# 13         0.11
# 14         0.24
# 15         0.60
# 16         0.52
# 17         0.42
# 18         0.51
# 19         0.45
# 20         0.34
# 21         0.60
# 22         0.20
# 23         0.85
# 24         0.38
# 25         0.32
# 26         0.64
# 27         0.30
# 28         0.28
# 29         0.32
# ..          ...
# 120       13.11
# 121        9.80
# 122       13.40
# 123        8.82
# 124       11.97
# 125       10.80
# 126        8.64
# 127        8.82
# 128       11.76
# 129        9.28
# 130       11.59
# 131       12.80
# 132       12.32
# 133        7.65
# 134        7.84
# 135       14.03
# 136       13.44
# 137        9.90
# 138        8.64
# 139       11.34
# 140       13.44
# 141       11.73
# 142        9.69
# 143       13.57
# 144       14.25
# 145       11.96
# 146        9.50
# 147       10.40
# 148       12.42
# 149        9.18
#
# [150 rows x 7 columns]

# %%
df.applymap(lambda v: np.log(v) if isinstance(v, float) else v)
# Out:
#      sepal length  sepal width  petal length  petal width class  wide petal  \
# 0        1.629241     1.252763      0.336472    -1.609438   SET           0
# 1        1.589235     1.098612      0.336472    -1.609438   SET           0
# 2        1.547563     1.163151      0.262364    -1.609438   SET           0
# 3        1.526056     1.131402      0.405465    -1.609438   SET           0
# 4        1.609438     1.280934      0.336472    -1.609438   SET           0
# 5        1.686399     1.360977      0.530628    -0.916291   SET           0
# 6        1.526056     1.223775      0.336472    -1.203973   SET           0
# 7        1.609438     1.223775      0.405465    -1.609438   SET           0
# 8        1.481605     1.064711      0.336472    -1.609438   SET           0
# 9        1.589235     1.131402      0.405465    -2.302585   SET           0
# 10       1.686399     1.308333      0.405465    -1.609438   SET           0
# 11       1.568616     1.223775      0.470004    -1.609438   SET           0
# 12       1.568616     1.098612      0.336472    -2.302585   SET           0
# 13       1.458615     1.098612      0.095310    -2.302585   SET           0
# 14       1.757858     1.386294      0.182322    -1.609438   SET           0
# 15       1.740466     1.481605      0.405465    -0.916291   SET           0
# 16       1.686399     1.360977      0.262364    -0.916291   SET           0
# 17       1.629241     1.252763      0.336472    -1.203973   SET           0
# 18       1.740466     1.335001      0.530628    -1.203973   SET           0
# 19       1.629241     1.335001      0.405465    -1.203973   SET           0
# 20       1.686399     1.223775      0.530628    -1.609438   SET           0
# 21       1.629241     1.308333      0.405465    -0.916291   SET           0
# 22       1.526056     1.280934      0.000000    -1.609438   SET           0
# 23       1.629241     1.193922      0.530628    -0.693147   SET           0
# 24       1.568616     1.223775      0.641854    -1.609438   SET           0
# 25       1.609438     1.098612      0.470004    -1.609438   SET           0
# 26       1.609438     1.223775      0.470004    -0.916291   SET           0
# 27       1.648659     1.252763      0.405465    -1.609438   SET           0
# 28       1.648659     1.223775      0.336472    -1.609438   SET           0
# 29       1.547563     1.163151      0.470004    -1.609438   SET           0
# ..            ...          ...           ...          ...   ...         ...
# 120      1.931521     1.163151      1.740466     0.832909   VIR           1
# 121      1.722767     1.029619      1.589235     0.693147   VIR           1
# 122      2.041220     1.029619      1.902108     0.693147   VIR           1
# 123      1.840550     0.993252      1.589235     0.587787   VIR           1
# 124      1.902108     1.193922      1.740466     0.741937   VIR           1
# 125      1.974081     1.163151      1.791759     0.587787   VIR           1
# 126      1.824549     1.029619      1.568616     0.587787   VIR           1
# 127      1.808289     1.098612      1.589235     0.587787   VIR           1
# 128      1.856298     1.029619      1.722767     0.741937   VIR           1
# 129      1.974081     1.098612      1.757858     0.470004   VIR           1
# 130      2.001480     1.029619      1.808289     0.641854   VIR           1
# 131      2.066863     1.335001      1.856298     0.693147   VIR           1
# 132      1.856298     1.029619      1.722767     0.788457   VIR           1
# 133      1.840550     1.029619      1.629241     0.405465   VIR           1
# 134      1.808289     0.955511      1.722767     0.336472   VIR           1
# 135      2.041220     1.098612      1.808289     0.832909   VIR           1
# 136      1.840550     1.223775      1.722767     0.875469   VIR           1
# 137      1.856298     1.131402      1.704748     0.587787   VIR           1
# 138      1.791759     1.098612      1.568616     0.587787   VIR           1
# 139      1.931521     1.131402      1.686399     0.741937   VIR           1
# 140      1.902108     1.131402      1.722767     0.875469   VIR           1
# 141      1.931521     1.131402      1.629241     0.832909   VIR           1
# 142      1.757858     0.993252      1.629241     0.641854   VIR           1
# 143      1.916923     1.163151      1.774952     0.832909   VIR           1
# 144      1.902108     1.193922      1.740466     0.916291   VIR           1
# 145      1.902108     1.098612      1.648659     0.832909   VIR           1
# 146      1.840550     0.916291      1.609438     0.641854   VIR           1
# 147      1.871802     1.098612      1.648659     0.693147   VIR           1
# 148      1.824549     1.223775      1.686399     0.832909   VIR           1
# 149      1.774952     1.098612      1.629241     0.587787   VIR           1
#
#      petal area
# 0     -1.272966
# 1     -1.272966
# 2     -1.347074
# 3     -1.203973
# 4     -1.272966
# 5     -0.385662
# 6     -0.867501
# 7     -1.203973
# 8     -1.272966
# 9     -1.897120
# 10    -1.203973
# 11    -1.139434
# 12    -1.966113
# 13    -2.207275
# 14    -1.427116
# 15    -0.510826
# 16    -0.653926
# 17    -0.867501
# 18    -0.673345
# 19    -0.798508
# 20    -1.078810
# 21    -0.510826
# 22    -1.609438
# 23    -0.162519
# 24    -0.967584
# 25    -1.139434
# 26    -0.446287
# 27    -1.203973
# 28    -1.272966
# 29    -1.139434
# ..          ...
# 120    2.573375
# 121    2.282382
# 122    2.595255
# 123    2.177022
# 124    2.482404
# 125    2.379546
# 126    2.156403
# 127    2.177022
# 128    2.464704
# 129    2.227862
# 130    2.450143
# 131    2.549445
# 132    2.511224
# 133    2.034706
# 134    2.059239
# 135    2.641198
# 136    2.598235
# 137    2.292535
# 138    2.156403
# 139    2.428336
# 140    2.598235
# 141    2.462150
# 142    2.271094
# 143    2.607861
# 144    2.656757
# 145    2.481568
# 146    2.251292
# 147    2.341806
# 148    2.519308
# 149    2.217027
#
# [150 rows x 7 columns]

# %%
df.groupby('class').mean()
# Out:
#        sepal length  sepal width  petal length  petal width  wide petal  \
# class
# SET           5.006        3.418         1.464        0.244         0.0
# VER           5.936        2.770         4.260        1.326         0.7
# VIR           6.588        2.974         5.552        2.026         1.0
#
#        petal area
# class
# SET        0.3628
# VER        5.7204
# VIR       11.2962

# %%
df.groupby('class').describe()
# Out:
#       petal area                                                         \
#            count     mean       std   min     25%     50%    75%    max
# class
# SET         50.0   0.3628  0.183248  0.11  0.2650   0.300   0.42   0.96
# VER         50.0   5.7204  1.368403  3.30  4.8600   5.615   6.75   8.64
# VIR         50.0  11.2962  2.157412  7.50  9.7175  11.445  12.79  15.87
#
#       petal length        ...  sepal width      wide petal                     \
#              count   mean ...          75%  max      count mean      std  min
# class                     ...
# SET           50.0  1.464 ...        3.675  4.4       50.0  0.0  0.00000  0.0
# VER           50.0  4.260 ...        3.000  3.4       50.0  0.7  0.46291  0.0
# VIR           50.0  5.552 ...        3.175  3.8       50.0  1.0  0.00000  1.0
#
#
#        25%  50%  75%  max
# class
# SET    0.0  0.0  0.0  0.0
# VER    0.0  1.0  1.0  1.0
# VIR    1.0  1.0  1.0  1.0
#
# [3 rows x 48 columns]

# %%
df.groupby('petal width')['class'].unique().to_frame()
# Out:
#                   class
# petal width
# 0.1               [SET]
# 0.2               [SET]
# 0.3               [SET]
# 0.4               [SET]
# 0.5               [SET]
# 0.6               [SET]
# 1.0               [VER]
# 1.1               [VER]
# 1.2               [VER]
# 1.3               [VER]
# 1.4          [VER, VIR]
# 1.5          [VER, VIR]
# 1.6          [VER, VIR]
# 1.7          [VER, VIR]
# 1.8          [VER, VIR]
# 1.9               [VIR]
# 2.0               [VIR]
# 2.1               [VIR]
# 2.2               [VIR]
# 2.3               [VIR]
# 2.4               [VIR]
# 2.5               [VIR]

# %%
df.groupby('class')['petal width']\
.agg({'delta': lambda x: x.max() - x.min(), 'max': np.max, 'min': np.min})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   """Entry point for launching an IPython kernel.
#        delta  max  min
# class
# SET      0.5  0.6  0.1
# VER      0.8  1.8  1.0
# VIR      1.1  2.5  1.4

# %%
fig, ax = plt.subplots(figsize=(7,7))
ax.scatter(df['sepal width'][:50], df['sepal length'][:50])
ax.set_ylabel('Sepal Length')
ax.set_xlabel('Sepal Width')
ax.set_title('Setosa Sepal Width vs. Sepal Length', fontsize=14, y=1.02)

# %%
import statsmodels.api as sm

y = df['sepal length'][:50]
x = df['sepal width'][:50]
X = sm.add_constant(x)

results = sm.OLS(y, X).fit()
print(results.summary())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           sepal length   R-squared:                       0.558
# Model:                            OLS   Adj. R-squared:                  0.548
# Method:                 Least Squares   F-statistic:                     60.52
# Date:                Wed, 07 Mar 2018   Prob (F-statistic):           4.75e-10
# Time:                        01:02:32   Log-Likelihood:                 2.0879
# No. Observations:                  50   AIC:                           -0.1759
# Df Residuals:                      48   BIC:                             3.648
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           2.6447      0.305      8.660      0.000       2.031       3.259
# sepal width     0.6909      0.089      7.779      0.000       0.512       0.869
# ==============================================================================
# Omnibus:                        0.252   Durbin-Watson:                   2.517
# Prob(Omnibus):                  0.882   Jarque-Bera (JB):                0.436
# Skew:                          -0.110   Prob(JB):                        0.804
# Kurtosis:                       2.599   Cond. No.                         34.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
fig, ax = plt.subplots(figsize=(7,7))
ax.plot(x, results.fittedvalues, label='regression line')
ax.scatter(x, y, label='data point', color='r')
ax.set_ylabel('Sepal Length')
ax.set_xlabel('Sepal Width')
ax.set_title('Setosa Sepal Width vs. Sepal Length', fontsize=14, y=1.02)
ax.legend(loc=2)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import train_test_split

clf = RandomForestClassifier(max_depth=5, n_estimators=10)

X = df.ix[:,:4]
y = df.ix[:,4]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)

clf.fit(X_train,y_train)

y_pred = clf.predict(X_test)

rf = pd.DataFrame(list(zip(y_pred, y_test)), columns=['predicted', 'actual'])
rf['correct'] = rf.apply(lambda r: 1 if r['predicted'] == r['actual'] else 0, axis=1)
    
rf
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
#    predicted actual  correct
# 0        VER    VER        1
# 1        VER    VER        1
# 2        SET    SET        1
# 3        SET    SET        1
# 4        SET    SET        1
# 5        SET    SET        1
# 6        VIR    VIR        1
# 7        SET    SET        1
# 8        VIR    VIR        1
# 9        SET    SET        1
# 10       VIR    VIR        1
# 11       VIR    VIR        1
# 12       VIR    VIR        1
# 13       VER    VER        1
# 14       SET    SET        1
# 15       VER    VER        1
# 16       SET    SET        1
# 17       VER    VER        1
# 18       SET    SET        1
# 19       SET    SET        1
# 20       SET    SET        1
# 21       SET    SET        1
# 22       VIR    VIR        1
# 23       VER    VER        1
# 24       VIR    VIR        1
# 25       VER    VER        1
# 26       SET    SET        1
# 27       SET    SET        1
# 28       VIR    VIR        1
# 29       VER    VER        1
# 30       VER    VER        1
# 31       SET    SET        1
# 32       SET    SET        1
# 33       VER    VER        1
# 34       VIR    VIR        1
# 35       VER    VIR        0
# 36       VIR    VIR        1
# 37       SET    SET        1
# 38       VER    VER        1
# 39       SET    SET        1
# 40       VER    VER        1
# 41       SET    SET        1
# 42       VIR    VIR        1
# 43       VIR    VIR        1
# 44       SET    SET        1

# %%
rf['correct'].sum()/rf['correct'].count()
# Out:
# 0.97777777777777775

# %%
f_importances = clf.feature_importances_
f_names = df.columns[:4]
f_std = np.std([tree.feature_importances_ for tree in clf.estimators_], axis=0)

zz = zip(f_importances, f_names, f_std)
zzs = sorted(zz, key=lambda x: x[0], reverse=True)

imps = [x[0] for x in zzs]
labels = [x[1] for x in zzs]
errs = [x[2] for x in zzs]

plt.bar(range(len(f_importances)), imps, color="r", yerr=errs, align="center")
plt.xticks(range(len(f_importances)), labels);

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.cross_validation import train_test_split

clf = OneVsRestClassifier(SVC(kernel='linear'))

X = df.ix[:,:4]
y = np.array(df.ix[:,4]).astype(str)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)

clf.fit(X_train,y_train)

y_pred = clf.predict(X_test)

rf = pd.DataFrame(list(zip(y_pred, y_test)), columns=['predicted', 'actual'])
rf['correct'] = rf.apply(lambda r: 1 if r['predicted'] == r['actual'] else 0, axis=1)
    
rf
# Out:
#    predicted actual  correct
# 0        VIR    VIR        1
# 1        VER    VER        1
# 2        VIR    VIR        1
# 3        SET    SET        1
# 4        SET    SET        1
# 5        VER    VER        1
# 6        VER    VER        1
# 7        SET    SET        1
# 8        SET    SET        1
# 9        SET    SET        1
# 10       VER    VER        1
# 11       SET    SET        1
# 12       VIR    VIR        1
# 13       VER    VER        1
# 14       VIR    VIR        1
# 15       VER    VER        1
# 16       VIR    VIR        1
# 17       VIR    VIR        1
# 18       VIR    VIR        1
# 19       VIR    VIR        1
# 20       SET    SET        1
# 21       VER    VER        1
# 22       VER    VER        1
# 23       SET    SET        1
# 24       VIR    VIR        1
# 25       SET    SET        1
# 26       VIR    VIR        1
# 27       SET    SET        1
# 28       VER    VIR        0
# 29       VER    VER        1
# 30       SET    SET        1
# 31       VER    VER        1
# 32       SET    SET        1
# 33       SET    SET        1
# 34       SET    SET        1
# 35       SET    SET        1
# 36       VIR    VIR        1
# 37       VER    VER        1
# 38       VIR    VIR        1
# 39       VER    VER        1
# 40       SET    SET        1
# 41       VER    VER        1
# 42       SET    SET        1
# 43       SET    SET        1
# 44       SET    SET        1

# %%
rf['correct'].sum()/rf['correct'].count()
# Out:
# 0.97777777777777775
